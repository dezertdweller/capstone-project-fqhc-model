# %% [markdown]
# # Importing Data
#
# Data is being fetched as an excel file directly from HRSA's data warehouse for federally qualified health centers (FQHCs). I'll start by importing 2022 data.

# %%
import pandas as pd
import numpy as np
from urllib.request import urlretrieve

# %%
url = 'https://www.hrsa.gov/sites/default/files/hrsa/foia/h80-2022.xlsx'
local_path = '/Users/katialopes-gilbert/repos/springboard-projects/capstone-project-fqhc-model/data/'
file_name = '2022-h80-data.xlsx'

# save file locally
urlretrieve(url, local_path + file_name)
# Out:
# ('/Users/katialopes-gilbert/repos/springboard-projects/capstone-project-fqhc-model/data/2022-h80-data.xlsx',
#  <http.client.HTTPMessage at 0x10e5bba90>)

# %%
# load file into dictionary
df = pd.read_excel(local_path + file_name, sheet_name=None)

# %% [markdown]
# ## Some key information about the 2022 UDS dataset:
#
# **How this data is collected:**
# Data is collected through HRSA's Uniform Data System report that health center grantees must fill out annually. In 2022, there were 1,370 entities that filled out the UDS report.
#
# **Missing Values Representation**
# 1. "-" represents no data entry by health center
# 2. "--" represents suppressed patient counts between 1-15 to protect patient privacy
# 3. "---" represents suppressed health center confidential data

# %%
df.keys()
# Out:
# dict_keys(['Coversheet', 'Evaluation Warning', 'HealthCenterInfo', 'HealthCenterSiteInfo', 'UIIDInfo', 'Table3A', 'Table3AHO', 'Table3APH', 'Table3AMHC', 'Table3B', 'Table3BHO', 'Table3BPH', 'Table3BMHC', 'Table4', 'Table4HO', 'Table4PH', 'Table4MHC', 'Table5', 'Table5HO', 'Table5PH', 'Table5MHC', 'Table6A', 'Table6AHO', 'Table6APH', 'Table6AMHC', 'Table6B', 'Table6BClinicalmeasures', 'Table7_1', 'Table7_2', 'Table7Clinicalmeasures', 'Table8A', 'Table9D', 'Table9E', 'HITInformation', 'OtherDataElements', 'Workforce', 'HealthCenterZipCodes', 'Crosswalk 2021-2022'])

# %%
# load sheets of interest into separate dataframes

health_centers = df['HealthCenterInfo']
health_center_sites = df['HealthCenterSiteInfo']
health_center_funding = df['Table9E']
health_center_zipcodes = df['HealthCenterZipCodes']
health_center_costs = df['Table8A']
personnel_and_visits = df['Table5']
patients_age = df['Table3A']
patients_race = df['Table3B']
patients_other_demographics = df['Table4']
patient_services_revenue = df['Table9D']

# %%
health_centers.head(3)
# Out:
#   BHCMISID GrantNumber  ReportingYear  \
# 0   010030  H80CS00803           2022
# 1   010040  H80CS00443           2022
# 2   010060  H80CS00741           2022
#
#                            HealthCenterName HealthCenterStreetAddress  \
# 0               HOLYOKE HEALTH CENTER, INC.              230 MAPLE ST
# 1          MAINE MOBILE HEALTH PROGRAM INC.          9 GREEN ST STE 1
# 2  FAIR HAVEN COMMUNITY HEALTH CLINIC, INC.             374 GRAND AVE
#
#   HealthCenterOtherAddress HealthCenterCity HealthCenterState  \
# 0                        -          Holyoke                MA
# 1                        -          Augusta                ME
# 2                        -        New Haven                CT
#
#   HealthCenterZIPCode           ProjectDirector ProjectDirectorPhone  \
# 0               01040  Alejandro  Esparza Perez        (413)420-2175
# 1               04330             Carol  Murphy        (917)209-3777
# 2               06513          Suzanne  Lagarde        (203)752-5129
#
#   ProjectDirectorPhoneExt ProjectDirectorFax          ProjectDirectorEmail  \
# 0                       -                  -  alejandro.esparza@hhcinc.org
# 1                       -                  -       cmurphy@mainemobile.org
# 2                       -      (203)777-8506           s.lagarde@fhchc.org
#
#    FundingCHC  FundingMHC  FundingHO  FundingPH UrbanRuralFlag
# 0        True       False      False      False          Urban
# 1       False        True      False      False          Rural
# 2        True       False      False      False          Urban

# %%
health_center_sites.head(3)
# Out:
#   BHCMISID GrantNumber             HealthCenterName  \
# 0   010030  H80CS00803  HOLYOKE HEALTH CENTER, INC.
# 1   010030  H80CS00803  HOLYOKE HEALTH CENTER, INC.
# 2   010030  H80CS00803  HOLYOKE HEALTH CENTER, INC.
#
#                       SiteName               SiteType SiteStatus LocationType  \
# 0       CHICOPEE HEALTH CENTER  Service Delivery Site     Active    Permanent
# 1  HOLYOKE HEALTH CENTER, INC.  Service Delivery Site     Active    Permanent
# 2         Holyoke Soldier Home  Service Delivery Site     Active    Permanent
#
#           LocationSetting OperationalSchedule CalendarSchedule  ...  SiteCity  \
# 0  All Other Clinic Types           Full-Time       Year-Round  ...  Chicopee
# 1  All Other Clinic Types           Full-Time       Year-Round  ...   Holyoke
# 2  All Other Clinic Types           Full-Time       Year-Round  ...   Holyoke
#
#   SiteState SiteZIPCode MailingStreetAddress MailingCity MailingState  \
# 0        MA  01013-3140         505-Front St    Chicopee           MA
# 1        MA  01040-5144         230-Maple St     Holyoke           MA
# 2        MA  01040-7002                    -           -            -
#
#   MailingZIPCode MedicaidNumber MedicaidPharmNumber                 DataAsof
# 0     01013-3140        1320874             0401480  12/31/2022 11:59 PM EST
# 1     01040-5144        1300237             0401480  12/31/2022 11:59 PM EST
# 2              -        1300237             0401480  12/31/2022 11:59 PM EST
#
# [3 rows x 24 columns]

# %%
health_center_funding.head(3)
# Out:
#   BHCMISID GrantNumber                        T9E_L1a_Ca  \
# 0      NaN         NaN  Migrant Health Center-Amount (a)
# 1   010030  H80CS00803                                 0
# 2   010040  H80CS00443                           1758567
#
#                            T9E_L1b_Ca  \
# 0  Community Health Center-Amount (a)
# 1                             5721128
# 2                                   -
#
#                                 T9E_L1c_Ca  \
# 0  Health Care for the Homeless-Amount (a)
# 1                                        0
# 2                                        -
#
#                                T9E_L1e_Ca  \
# 0  Public Housing Primary Care-Amount (a)
# 1                                       0
# 2                                       -
#
#                                           T9E_L1g_Ca  \
# 0  Total Health Center (Sum of Lines 1a through 1...
# 1                                            5721128
# 2                                            1758567
#
#                                           T9E_L1k_Ca  \
# 0  Capital Development Grants, including School-B...
# 1                                                  0
# 2                                                  -
#
#                                           T9e_L1l_Ca  \
# 0  Coronavirus Preparedness and Response Suppleme...
# 1                                                  0
# 2                                               1256
#
#                                           T9e_L1m_Ca  ...  \
# 0  Coronavirus Aid, Relief, and Economic Security...  ...
# 1                                                  0  ...
# 2                                                  -  ...
#
#                                T9E_L6a_Other  \
# 0  State/Local Indigent Care Programs-Source
# 1                                        HSN
# 2                                          -
#
#                                       T9E_L6a_Ca  \
# 0  State/Local Indigent Care Programs-Amount (a)
# 1                                        1442182
# 2                                              -
#
#                                    T9E_L7_Other  \
# 0  Local Government Grants and Contracts-Source
# 1                                             -
# 2                                             -
#
#                                           T9E_L7_Ca  \
# 0  Local Government Grants and Contracts-Amount (a)
# 1                                                 0
# 2                                                 -
#
#                                         T9E_L8_Other  \
# 0     Foundation/Private Grants and Contracts-Source
# 1  MA League - CHWs, La Linda Manita, Project Bre...
# 2                               MeHAF Advocacy Grant
#
#                                            T9E_L8_Ca  \
# 0  Foundation/Private Grants and Contracts-Amount...
# 1                                             764680
# 2                                              25000
#
#                                            T9E_L9_Ca  \
# 0  Total Non-Federal Grants and Contracts (Sum of...
# 1                                            5122518
# 2                                              25000
#
#                                        T9E_L10_Other  \
# 0  Other Revenue (non-patient service revenue not...
# 1  Rental Income from tenants,\nInterest Income, ...
# 2  Interest $703; Other Income $33,875; Donations...
#
#                                           T9E_L10_Ca  \
# 0  Other Revenue (non-patient service revenue not...
# 1                                           14258919
# 2                                              36578
#
#                                           T9E_L11_Ca
# 0  Total Revenue (Sum of Lines 1 + 5 + 9 + 10)-Am...
# 1                                           28330029
# 2                                            2320228
#
# [3 rows x 35 columns]

# %%
health_center_costs.head(3)
# Out:
#   BHCMISID GrantNumber                           T8a_L1_Ca  \
# 0      NaN         NaN  Medical Personnel-Accrued Cost (a)
# 1      ---         ---                                 ---
# 2   010040  H80CS00443                              405175
#
#                                            T8a_L1_Cb  \
# 0  Medical Personnel-Allocation of Facility and N...
# 1                                                ---
# 2                                             251125
#
#                                            T8a_L1_Cc  \
# 0  Medical Personnel-Total Cost After Allocation ...
# 1                                                ---
# 2                                             656300
#
#                         T8a_L2_Ca  \
# 0  Lab and X-ray-Accrued Cost (a)
# 1                             ---
# 2                           20990
#
#                                            T8a_L2_Cb  \
# 0  Lab and X-ray-Allocation of Facility and Non-C...
# 1                                                ---
# 2                                              11507
#
#                                            T8a_L2_Cc  \
# 0  Lab and X-ray-Total Cost After Allocation of F...
# 1                                                ---
# 2                                              32497
#
#                                T8a_L3_Ca  \
# 0  Medical/Other Direct-Accrued Cost (a)
# 1                                    ---
# 2                                  55634
#
#                                            T8a_L3_Cb  ...  \
# 0  Medical/Other Direct-Allocation of Facility an...  ...
# 1                                                ---  ...
# 2                                              30500  ...
#
#                                           T8a_L13_Cb  \
# 0  Total Enabling and Other Services (Sum of Line...
# 1                                                ---
# 2                                             397592
#
#                                           T8a_L13_Cc  \
# 0  Total Enabling and Other Services (Sum of Line...
# 1                                                ---
# 2                                            1024600
#
#                   T8a_L14_Ca                                      T8a_L15_Ca  \
# 0  Facility-Accrued Cost (a)  Non-Clinical Support Services-Accrued Cost (a)
# 1                        ---                                             ---
# 2                      89179                                          742777
#
#                                           T8a_L16_Ca  \
# 0  Total Facility and Non-Clinical Support Servic...
# 1                                                ---
# 2                                             831956
#
#                                           T8a_L17_Ca  \
# 0  Total Accrued Costs (Sum of Lines 4 + 10 + 13 ...
# 1                                                ---
# 2                                            2183264
#
#                                           T8a_L17_Cc  \
# 0  Total Accrued Costs (Sum of Lines 4 + 10 + 13 ...
# 1                                                ---
# 2                                            2183264
#
#                                        T8a_L18_Other  \
# 0  Value of Donated Facilities, Services, and Sup...
# 1                                                ---
# 2  Donated services represent the difference betw...
#
#                                           T8a_L18_Cc  \
# 0  Value of Donated Facilities, Services, and Sup...
# 1                                                ---
# 2                                             105231
#
#                                           T8a_L19_Cc
# 0  Total with Donations (Sum of Lines 17 and 18)-...
# 1                                                ---
# 2                                            2288495
#
# [3 rows x 76 columns]

# %%
health_center_zipcodes.head(3)
# Out:
#   BHCMISID GrantNumber  ReportingYear ZipCode ZipCodeType  \
# 0   010030  H80CS00803           2022   01011     ZipCode
# 1   010030  H80CS00803           2022   01013     ZipCode
# 2   010030  H80CS00803           2022   01014     ZipCode
#
#   None_UninsuredPatients Medicaid_CHIP_OtherPublicPatients MedicarePatients  \
# 0                     --                                --                0
# 1                     61                              1346              385
# 2                      0                                --               --
#
#   PrivatePatients TotalNumberofPatients
# 0              --                    --
# 1             182                  1974
# 2               0                    21

# %%
personnel_and_visits.head(3)
# Out:
#   BHCMISID GrantNumber                    T5_L1_Ca  \
# 0      NaN         NaN  Family Physicians-FTEs (a)
# 1      ---         ---                         ---
# 2   010040  H80CS00443                        0.92
#
#                               T5_L1_Cb                              T5_L1_Cb2  \
# 0  Family Physicians-Clinic Visits (b)  Family Physicians-Virtual Visits (b2)
# 1                                  ---                                    ---
# 2                                 1013                                      3
#
#                          T5_L2_Ca                                 T5_L2_Cb  \
# 0  General Practitioners-FTEs (a)  General Practitioners-Clinic Visits (b)
# 1                             ---                                      ---
# 2                               0                                        0
#
#                                    T5_L2_Cb2             T5_L3_Ca  \
# 0  General Practitioners-Virtual Visits (b2)  Internists-FTEs (a)
# 1                                        ---                  ---
# 2                                          0                  0.1
#
#                        T5_L3_Cb  ...  \
# 0  Internists-Clinic Visits (b)  ...
# 1                           ---  ...
# 2                            16  ...
#
#                                          T5_L21f_Cb2  \
# 0  Licensed Clinical Psychologists-Virtual Visits...
# 1                                                ---
# 2                                                  -
#
#                                      T5_L21f_Cc  \
# 0  Licensed Clinical Psychologists-Patients (c)
# 1                                           ---
# 2                                             -
#
#                                        T5_L21g_Ca1  \
# 0  Licensed Clinical Social Workers-Personnel (a1)
# 1                                              ---
# 2                                                2
#
#                                           T5_L21g_Cb  \
# 0  Licensed Clinical Social Workers-Clinic Visits...
# 1                                                ---
# 2                                                  6
#
#                                          T5_L21g_Cb2  \
# 0  Licensed Clinical Social Workers-Virtual Visit...
# 1                                                ---
# 2                                                 10
#
#                                       T5_L21g_Cc  \
# 0  Licensed Clinical Social Workers-Patients (c)
# 1                                            ---
# 2                                              7
#
#                                          T5_L21h_Ca1  \
# 0  Other Licensed Mental Health Providers-Personn...
# 1                                                ---
# 2                                                  -
#
#                                           T5_L21h_Cb  \
# 0  Other Licensed Mental Health Providers-Clinic ...
# 1                                                ---
# 2                                                  -
#
#                                          T5_L21h_Cb2  \
# 0  Other Licensed Mental Health Providers-Virtual...
# 1                                                ---
# 2                                                  -
#
#                                           T5_L21h_Cc
# 0  Other Licensed Mental Health Providers-Patient...
# 1                                                ---
# 2                                                  -
#
# [3 rows x 176 columns]

# %%
patients_age.head(3)
# Out:
#   BHCMISID GrantNumber                      T3a_L1_Ca  \
# 0      NaN         NaN  Under age 1-Male Patients (a)
# 1   010030  H80CS00803                             81
# 2   010040  H80CS00443                             --
#
#                          T3a_L1_Cb                T3a_L2_Ca  \
# 0  Under age 1-Female Patients (b)  Age 1-Male Patients (a)
# 1                               69                      104
# 2                               --                       --
#
#                    T3a_L2_Cb                T3a_L3_Ca  \
# 0  Age 1-Female Patients (b)  Age 2-Male Patients (a)
# 1                         99                      112
# 2                          0                       --
#
#                    T3a_L3_Cb                T3a_L4_Ca  \
# 0  Age 2-Female Patients (b)  Age 3-Male Patients (a)
# 1                        113                      126
# 2                         --                       --
#
#                    T3a_L4_Cb  ...                    T3a_L35_Ca  \
# 0  Age 3-Female Patients (b)  ...  Ages 70–74-Male Patients (a)
# 1                        120  ...                           364
# 2                         --  ...                            --
#
#                        T3a_L35_Cb                    T3a_L36_Ca  \
# 0  Ages 70–74-Female Patients (b)  Ages 75–79-Male Patients (a)
# 1                             411                           226
# 2                              --                            --
#
#                        T3a_L36_Cb                    T3a_L37_Ca  \
# 0  Ages 75–79-Female Patients (b)  Ages 80–84-Male Patients (a)
# 1                             294                           141
# 2                              --                             0
#
#                        T3a_L37_Cb                         T3a_L38_Ca  \
# 0  Ages 80–84-Female Patients (b)  Age 85 and over-Male Patients (a)
# 1                             161                                126
# 2                              --                                  0
#
#                             T3a_L38_Cb  \
# 0  Age 85 and over-Female Patients (b)
# 1                                  121
# 2                                    0
#
#                                           T3a_L39_Ca  \
# 0  Total Patients (Sum of Lines 1-38)-Male Patien...
# 1                                               8821
# 2                                                609
#
#                                           T3a_L39_Cb
# 0  Total Patients (Sum of Lines 1-38)-Female Pati...
# 1                                              10323
# 2                                                241
#
# [3 rows x 80 columns]

# %%
patients_race.head(3)
# Out:
#   BHCMISID GrantNumber                       T3b_L1_Ca  \
# 0      NaN         NaN  Asian-Hispanic or Latino/a (a)
# 1   010030  H80CS00803                              --
# 2   010040  H80CS00443                               0
#
#                             T3b_L1_Cb                            T3b_L1_Cd  \
# 0  Asian-Non-Hispanic or Latino/a (b)  Asian-Total (d) (Sum Columns a+b+c)
# 1                                 148                                  158
# 2                                   0                                    0
#
#                                  T3b_L2a_Ca  \
# 0  Native Hawaiian-Hispanic or Latino/a (a)
# 1                                       215
# 2                                         0
#
#                                      T3b_L2a_Cb  \
# 0  Native Hawaiian-Non-Hispanic or Latino/a (b)
# 1                                            17
# 2                                             0
#
#                                       T3b_L2a_Cd  \
# 0  Native Hawaiian-Total (d) (Sum Columns a+b+c)
# 1                                            232
# 2                                              0
#
#                                         T3b_L2b_Ca  \
# 0  Other Pacific Islander-Hispanic or Latino/a (a)
# 1                                               --
# 2                                                0
#
#                                           T3b_L2b_Cb  ...         T3b_L18a_Ca  \
# 0  Other Pacific Islander-Non-Hispanic or Latino/...  ...  Unknown-Number (a)
# 1                                                 --  ...                  51
# 2                                                 --  ...                   0
#
#                                           T3b_L19_Ca       T3b_L20_Ca  \
# 0  Total Patients (Sum of Lines 13 to 18a)-Number...  Male-Number (a)
# 1                                              19144             7744
# 2                                                850              609
#
#           T3b_L21_Ca                                         T3b_L22_Ca  \
# 0  Female-Number (a)  Transgender Man/Transgender Male/Transmasculin...
# 1               9138                                                 33
# 2                241                                                  0
#
#                                           T3b_L23_Ca        T3b_L24_Ca  \
# 0  Transgender Woman/Transgender Female/Transfemi...  Other-Number (a)
# 1                                                 28                64
# 2                                                  0                 0
#
#                          T3b_L25_Ca         T3b_L25a_Ca  \
# 0  Chose not to disclose-Number (a)  Unknown-Number (a)
# 1                              2109                  28
# 2                                 0                   0
#
#                                           T3b_L26_Ca
# 0  Total Patients (Sum of Lines 20 to 25a)-Number...
# 1                                              19144
# 2                                                850
#
# [3 rows x 51 columns]

# %%
patients_other_demographics.head(3)
# Out:
#   BHCMISID GrantNumber                               T4_L1_Ca  \
# 0      NaN         NaN  100% and below-Number of Patients (a)
# 1   010030  H80CS00803                                   2706
# 2   010040  H80CS00443                                    768
#
#                           T4_L2_Ca                         T4_L3_Ca  \
# 0  101–150%-Number of Patients (a)  151–200%-Number of Patients (a)
# 1                              184                              103
# 2                               68                               --
#
#                            T4_L4_Ca                        T4_L5_Ca  \
# 0  Over 200%-Number of Patients (a)  Unknown-Number of Patients (a)
# 1                               168                           15983
# 2                                --                               0
#
#                                           T4_L6_Ca  \
# 0  TOTAL (Sum of Lines 1–5)-Number of Patients (a)
# 1                                            19144
# 2                                              850
#
#                             T4_L7_Ca                         T4_L7_Cb  ...  \
# 0  None/Uninsured-0-17 years old (a)  None/Uninsured-18 and older (b)  ...
# 1                                104                              609  ...
# 2                                 35                              734  ...
#
#                                            T4_L18_Ca  \
# 0  Transitional (330h awardees only)-Number of Pa...
# 1                                                  -
# 2                                                  -
#
#                                            T4_L19_Ca  \
# 0  Doubling Up (330h awardees only)-Number of Pat...
# 1                                                  -
# 2                                                  -
#
#                                            T4_L20_Ca  \
# 0  Street (330h awardees only)-Number of Patients...
# 1                                                  -
# 2                                                  -
#
#                                           T4_L21a_Ca  \
# 0  Permanent Supportive Housing (330h awardees on...
# 1                                                  -
# 2                                                  -
#
#                                            T4_L21_Ca  \
# 0  Other (330h awardees only)-Number of Patients (a)
# 1                                                  -
# 2                                                  -
#
#                                            T4_L22_Ca  \
# 0  Unknown (330h awardees only)-Number of Patient...
# 1                                                  -
# 2                                                  -
#
#                                            T4_L23_Ca  \
# 0  Total Homeless (All health centers report this...
# 1                                               2998
# 2                                                 --
#
#                                            T4_L24_Ca  \
# 0  Total School-Based Service Site Patients (All ...
# 1                                                  0
# 2                                                  0
#
#                                            T4_L25_Ca  \
# 0  Total Veterans (All health centers report this...
# 1                                                332
# 2                                                 --
#
#                                            T4_L26_Ca
# 0  Total Patients Served at a Health Center Locat...
# 1                                              19144
# 2                                                  0
#
# [3 rows x 60 columns]

# %%
patient_services_revenue.head(3)
# Out:
#   BHCMISID GrantNumber                                          T9D_L1_Ca  \
# 0      NaN         NaN  Medicaid Non-Managed Care-Full Charges This Pe...
# 1      ---         ---                                                ---
# 2   010040  H80CS00443                                               4963
#
#                                            T9D_L1_Cb  \
# 0  Medicaid Non-Managed Care-Amount Collected Thi...
# 1                                                ---
# 2                                                151
#
#                                           T9D_L1_Cc1  \
# 0  Medicaid Non-Managed Care-Collection of Reconc...
# 1                                                ---
# 2                                                  -
#
#                                           T9D_L1_Cc2  \
# 0  Medicaid Non-Managed Care-Collection of Reconc...
# 1                                                ---
# 2                                                  -
#
#                                           T9D_L1_Cc3  \
# 0  Medicaid Non-Managed Care-Collection of Other ...
# 1                                                ---
# 2                                                  -
#
#                                        T9D_L1_Cc4  \
# 0  Medicaid Non-Managed Care-Penalty/Payback (c4)
# 1                                             ---
# 2                                               -
#
#                                    T9D_L1_Cd  \
# 0  Medicaid Non-Managed Care-Adjustments (d)
# 1                                        ---
# 2                                         99
#
#                                           T9D_L2a_Ca  ...  \
# 0  Medicaid Managed Care (capitated)-Full Charges...  ...
# 1                                                ---  ...
# 2                                                  -  ...
#
#                         T9D_L13_Cf  \
# 0  Self-Pay-Bad Debt Write-Off (f)
# 1                              ---
# 2                             1235
#
#                                           T9D_L14_Ca  \
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Full ...
# 1                                                ---
# 2                                             636869
#
#                                           T9D_L14_Cb  \
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Amoun...
# 1                                                ---
# 2                                               2724
#
#                                          T9D_L14_Cc1  \
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Colle...
# 1                                                ---
# 2                                                  -
#
#                                          T9D_L14_Cc2  \
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Colle...
# 1                                                ---
# 2                                                  -
#
#                                          T9D_L14_Cc3  \
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Colle...
# 1                                                ---
# 2                                                  -
#
#                                          T9D_L14_Cc4  \
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Penal...
# 1                                                ---
# 2                                                  -
#
#                                           T9D_L14_Cd  \
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Adjus...
# 1                                                ---
# 2                                                184
#
#                                           T9D_L14_Ce  \
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Slidi...
# 1                                                ---
# 2                                             617158
#
#                                           T9D_L14_Cf
# 0  TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Bad D...
# 1                                                ---
# 2                                               1235
#
# [3 rows x 124 columns]

# %% [markdown]
# # Data Cleaning
#
# Write up an initial overview of how data will need to be cleaned here.

# %% [markdown]
# I am going to need to rename the columns for several of the dataframes. The current names are abbreviations that will be too hard to understand by checking HRSA's reference for each one. I'll create a function to keep the first and second values of the original column names, and replace all other columns names for the values in the first row.

# %%
def rename_columns(df):
    """Renames dataframe columns by preserving the first two column names
       and setting the first row as the new column names for all columns after the 
       2nd column."""
    
    # save the first two column names
    original_columns = df.columns[:2]
    # create new column names by combining saved columns + first row
    new_column_names = list(original_columns) + df.iloc[0, 2:].tolist()
    # rename columns
    df.columns = new_column_names
    # drop redundant first row
    df = df.drop(index=0, inplace=True)
    
    return df

# %%
dataframes_to_rename = [health_center_funding, health_center_costs, patient_services_revenue, personnel_and_visits, 
                        patients_age, patients_race, patients_other_demographics]

renamed_dataframes = [rename_columns(df) for df in dataframes_to_rename]

# %%
health_center_funding.head(2)
# Out:
#   BHCMISID GrantNumber Migrant Health Center-Amount (a)  \
# 1   010030  H80CS00803                                0
# 2   010040  H80CS00443                          1758567
#
#   Community Health Center-Amount (a) Health Care for the Homeless-Amount (a)  \
# 1                            5721128                                       0
# 2                                  -                                       -
#
#   Public Housing Primary Care-Amount (a)  \
# 1                                      0
# 2                                      -
#
#   Total Health Center (Sum of Lines 1a through 1e)-Amount (a)  \
# 1                                            5721128
# 2                                            1758567
#
#   Capital Development Grants, including School-Based Service Site Capital Grants-Amount (a)  \
# 1                                                  0
# 2                                                  -
#
#   Coronavirus Preparedness and Response Supplemental Appropriations Act (H8C)-Amount (a)  \
# 1                                                  0
# 2                                               1256
#
#   Coronavirus Aid, Relief, and Economic Security Act (CARES) (H8D)-Amount (a)  \
# 1                                                  0
# 2                                                  -
#
#    ... State/Local Indigent Care Programs-Source  \
# 1  ...                                       HSN
# 2  ...                                         -
#
#   State/Local Indigent Care Programs-Amount (a)  \
# 1                                       1442182
# 2                                             -
#
#   Local Government Grants and Contracts-Source  \
# 1                                            -
# 2                                            -
#
#   Local Government Grants and Contracts-Amount (a)  \
# 1                                                0
# 2                                                -
#
#       Foundation/Private Grants and Contracts-Source  \
# 1  MA League - CHWs, La Linda Manita, Project Bre...
# 2                               MeHAF Advocacy Grant
#
#   Foundation/Private Grants and Contracts-Amount (a)  \
# 1                                             764680
# 2                                              25000
#
#   Total Non-Federal Grants and Contracts (Sum of Lines 6 + 6a + 7 + 8)-Amount (a)  \
# 1                                            5122518
# 2                                              25000
#
#   Other Revenue (non-patient service revenue not reported elsewhere)-Source  \
# 1  Rental Income from tenants,\nInterest Income, ...
# 2  Interest $703; Other Income $33,875; Donations...
#
#   Other Revenue (non-patient service revenue not reported elsewhere)-Amount (a)  \
# 1                                           14258919
# 2                                              36578
#
#   Total Revenue (Sum of Lines 1 + 5 + 9 + 10)-Amount (a)
# 1                                           28330029
# 2                                            2320228
#
# [2 rows x 35 columns]

# %%
personnel_and_visits.head(3)
# Out:
#   BHCMISID GrantNumber Family Physicians-FTEs (a)  \
# 1      ---         ---                        ---
# 2   010040  H80CS00443                       0.92
# 3   010060  H80CS00741                       4.84
#
#   Family Physicians-Clinic Visits (b) Family Physicians-Virtual Visits (b2)  \
# 1                                 ---                                   ---
# 2                                1013                                     3
# 3                                7695                                  2700
#
#   General Practitioners-FTEs (a) General Practitioners-Clinic Visits (b)  \
# 1                            ---                                     ---
# 2                              0                                       0
# 3                              0                                       0
#
#   General Practitioners-Virtual Visits (b2) Internists-FTEs (a)  \
# 1                                       ---                 ---
# 2                                         0                 0.1
# 3                                         0                4.48
#
#   Internists-Clinic Visits (b)  ...  \
# 1                          ---  ...
# 2                           16  ...
# 3                         7506  ...
#
#   Licensed Clinical Psychologists-Virtual Visits (b2)  \
# 1                                                ---
# 2                                                  -
# 3                                                  3
#
#   Licensed Clinical Psychologists-Patients (c)  \
# 1                                          ---
# 2                                            -
# 3                                           12
#
#   Licensed Clinical Social Workers-Personnel (a1)  \
# 1                                             ---
# 2                                               2
# 3                                               3
#
#   Licensed Clinical Social Workers-Clinic Visits (b)  \
# 1                                                ---
# 2                                                  6
# 3                                                 93
#
#   Licensed Clinical Social Workers-Virtual Visits (b2)  \
# 1                                                ---
# 2                                                 10
# 3                                                  9
#
#   Licensed Clinical Social Workers-Patients (c)  \
# 1                                           ---
# 2                                             7
# 3                                            13
#
#   Other Licensed Mental Health Providers-Personnel (a1)  \
# 1                                                ---
# 2                                                  -
# 3                                                  8
#
#   Other Licensed Mental Health Providers-Clinic Visits (b)  \
# 1                                                ---
# 2                                                  -
# 3                                                102
#
#   Other Licensed Mental Health Providers-Virtual Visits (b2)  \
# 1                                                ---
# 2                                                  -
# 3                                                174
#
#   Other Licensed Mental Health Providers-Patients (c)
# 1                                                ---
# 2                                                  -
# 3                                                 72
#
# [3 rows x 176 columns]

# %%
# create a dictionary with df names as keys and dfs as values
dataframes_dict = {'health_centers': health_centers, 
              'health_center_sites': health_center_sites, 
              'health_center_funding': health_center_funding, 
              'health_center_zipcodes': health_center_zipcodes,
              'health_center_costs': health_center_costs,
              'patient_services_revenue': patient_services_revenue, 
              'personnel_and_visits': personnel_and_visits, 
              'patients_age': patients_age, 
              'patients_race': patients_race, 
              'patients_other_demographics': patients_other_demographics}

# %%
def dataframe_summary(dataframe_dict, key):
    """
    A function that provides an overview of a dataframe's structure and columns.
    
    Parameters:
    - dataframes_dict: Dict[str, pd.DataFrame], a dictionary of DataFrames.
    - key: str, the key for the DataFrame to process.

    Returns:
    An overview of a dataframe's shape and column names."""
    # access the df with its key
    df = dataframe_dict[key]

    # print relevant information about the df
    print(f'The {key} dataframe has a shape of {df.shape}.')
    print()
    print(f'The {key} dataframe has the following columns and number of values: ')
    print(df.columns)
    print()
    print('-----------------------------------')

# %%
for key in dataframes_dict.keys():
    dataframe_summary(dataframes_dict, key)
# Out:
# The health_centers dataframe has a shape of (1370, 19).
#
# The health_centers dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', 'ReportingYear', 'HealthCenterName',
#        'HealthCenterStreetAddress', 'HealthCenterOtherAddress',
#        'HealthCenterCity', 'HealthCenterState', 'HealthCenterZIPCode',
#        'ProjectDirector', 'ProjectDirectorPhone', 'ProjectDirectorPhoneExt',
#        'ProjectDirectorFax', 'ProjectDirectorEmail', 'FundingCHC',
#        'FundingMHC', 'FundingHO', 'FundingPH', 'UrbanRuralFlag'],
#       dtype='object')
#
# -----------------------------------
# The health_center_sites dataframe has a shape of (14987, 24).
#
# The health_center_sites dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', 'HealthCenterName', 'SiteName', 'SiteType',
#        'SiteStatus', 'LocationType', 'LocationSetting', 'OperationalSchedule',
#        'CalendarSchedule', 'TotalWeeklyHoursOfOperation',
#        'ServiceAreaPopulation', 'SiteOperatedBy', 'SiteStreetAddress',
#        'SiteCity', 'SiteState', 'SiteZIPCode', 'MailingStreetAddress',
#        'MailingCity', 'MailingState', 'MailingZIPCode', 'MedicaidNumber',
#        'MedicaidPharmNumber', 'DataAsof'],
#       dtype='object')
#
# -----------------------------------
# The health_center_funding dataframe has a shape of (1370, 35).
#
# The health_center_funding dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', 'Migrant Health Center-Amount (a)',
#        'Community Health Center-Amount (a)',
#        'Health Care for the Homeless-Amount (a)',
#        'Public Housing Primary Care-Amount (a)',
#        'Total Health Center (Sum of Lines 1a through 1e)-Amount (a)',
#        'Capital Development Grants, including School-Based Service Site Capital Grants-Amount (a)',
#        'Coronavirus Preparedness and Response Supplemental Appropriations Act (H8C)-Amount (a)',
#        'Coronavirus Aid, Relief, and Economic Security Act (CARES) (H8D)-Amount (a)',
#        'Expanding Capacity for Coronavirus Testing (ECT) (H8E and LAL ECT)-Amount (a)',
#        'American Rescue Plan (ARP) (H8F, L2C, C8E)-Amount (a)',
#        'Other COVID-19-Related Funding from BPHC-Source',
#        'Other COVID-19-Related Funding from BPHC-Amount (a)',
#        'Total COVID-19 Supplemental (Sum of Lines 1l through 1p)-Amount (a)',
#        'Total BPHC Grants (Sum of Lines 1g + 1k + 1q)-Amount (a)',
#        'Ryan White Part C HIV Early Intervention-Amount (a)',
#        'Other Federal Grants-Source', 'Other Federal Grants-Amount (a)',
#        'Medicare and Medicaid EHR Incentive Payments for Eligible Providers-Amount (a)',
#        'Provider Relief Fund-Source', 'Provider Relief Fund-Amount (a)',
#        'Total Other Federal Grants (Sum of Lines 2 through 3b)-Amount (a)',
#        'State Government Grants and Contracts-Source',
#        'State Government Grants and Contracts-Amount (a)',
#        'State/Local Indigent Care Programs-Source',
#        'State/Local Indigent Care Programs-Amount (a)',
#        'Local Government Grants and Contracts-Source',
#        'Local Government Grants and Contracts-Amount (a)',
#        'Foundation/Private Grants and Contracts-Source',
#        'Foundation/Private Grants and Contracts-Amount (a)',
#        'Total Non-Federal Grants and Contracts (Sum of Lines 6 + 6a + 7 + 8)-Amount (a)',
#        'Other Revenue (non-patient service revenue not reported elsewhere)-Source',
#        'Other Revenue (non-patient service revenue not reported elsewhere)-Amount (a)',
#        'Total Revenue (Sum of Lines 1 + 5 + 9 + 10)-Amount (a)'],
#       dtype='object')
#
# -----------------------------------
# The health_center_zipcodes dataframe has a shape of (97142, 10).
#
# The health_center_zipcodes dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', 'ReportingYear', 'ZipCode', 'ZipCodeType',
#        'None_UninsuredPatients', 'Medicaid_CHIP_OtherPublicPatients',
#        'MedicarePatients', 'PrivatePatients', 'TotalNumberofPatients'],
#       dtype='object')
#
# -----------------------------------
# The health_center_costs dataframe has a shape of (1370, 76).
#
# The health_center_costs dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', 'Medical Personnel-Accrued Cost (a)',
#        'Medical Personnel-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Medical Personnel-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Lab and X-ray-Accrued Cost (a)',
#        'Lab and X-ray-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Lab and X-ray-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Medical/Other Direct-Accrued Cost (a)',
#        'Medical/Other Direct-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Medical/Other Direct-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Total Medical Care Services (Sum of Lines 1 through 3)-Accrued Cost (a)',
#        'Total Medical Care Services (Sum of Lines 1 through 3)-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Total Medical Care Services (Sum of Lines 1 through 3)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Dental-Accrued Cost (a)',
#        'Dental-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Dental-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Mental Health-Accrued Cost (a)',
#        'Mental Health-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Mental Health-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Substance Use Disorder-Accrued Cost (a)',
#        'Substance Use Disorder-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Substance Use Disorder-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Pharmacy (not including pharmaceuticals)-Accrued Cost (a)',
#        'Pharmacy (not including pharmaceuticals)-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Pharmacy (not including pharmaceuticals)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Pharmaceuticals-Accrued Cost (a)',
#        'Pharmaceuticals-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Other Professional-Others', 'Other Professional-Accrued Cost (a)',
#        'Other Professional-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Other Professional-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Vision-Accrued Cost (a)',
#        'Vision-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Vision-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Total Other Clinical Services (Sum of Lines 5 through 9a)-Accrued Cost (a)',
#        'Total Other Clinical Services (Sum of Lines 5 through 9a)-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Total Other Clinical Services (Sum of Lines 5 through 9a)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Case Management-Accrued Cost (a)',
#        'Case Management-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Transportation-Accrued Cost (a)',
#        'Transportation-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Outreach-Accrued Cost (a)',
#        'Outreach-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Patient and Community Education-Accrued Cost (a)',
#        'Patient and Community Education-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Eligibility Assistance-Accrued Cost (a)',
#        'Eligibility Assistance-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Interpretation Services-Accrued Cost (a)',
#        'Interpretation Services-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Other Enabling Services-Others',
#        'Other Enabling Services-Accrued Cost (a)',
#        'Other Enabling Services-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Community Health Workers-Accrued Cost (a)',
#        'Community Health Workers-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Total Enabling Services (Sum of Lines 11a through 11h)-Accrued Cost (a)',
#        'Total Enabling Services (Sum of Lines 11a through 11h)-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Total Enabling Services (Sum of Lines 11a through 11h)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Other Program-Related Services-Others',
#        'Other Program-Related Services-Accrued Cost (a)',
#        'Other Program-Related Services-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Other Program-Related Services-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Quality Improvement-Accrued Cost (a)',
#        'Quality Improvement-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Quality Improvement-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Total Enabling and Other Services (Sum of Lines 11, 12, and 12a)-Accrued Cost (a)',
#        'Total Enabling and Other Services (Sum of Lines 11, 12, and 12a)-Allocation of Facility and Non-Clinical Support Services (b)',
#        'Total Enabling and Other Services (Sum of Lines 11, 12, and 12a)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Facility-Accrued Cost (a)',
#        'Non-Clinical Support Services-Accrued Cost (a)',
#        'Total Facility and Non-Clinical Support Services (Sum of Lines 14 and 15)-Accrued Cost (a)',
#        'Total Accrued Costs (Sum of Lines 4 + 10 + 13 + 16)-Accrued Cost (a)',
#        'Total Accrued Costs (Sum of Lines 4 + 10 + 13 + 16)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Value of Donated Facilities, Services, and Supplies-Others',
#        'Value of Donated Facilities, Services, and Supplies-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
#        'Total with Donations (Sum of Lines 17 and 18)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)'],
#       dtype='object')
#
# -----------------------------------
# The patient_services_revenue dataframe has a shape of (1370, 124).
#
# The patient_services_revenue dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber',
#        'Medicaid Non-Managed Care-Full Charges This Period (a)',
#        'Medicaid Non-Managed Care-Amount Collected This Period (b)',
#        'Medicaid Non-Managed Care-Collection of Reconciliation/Wraparound Current Year (c1)',
#        'Medicaid Non-Managed Care-Collection of Reconciliation/Wraparound Previous Years (c2)',
#        'Medicaid Non-Managed Care-Collection of Other Payments: P4P, Risk Pools, etc. (c3)',
#        'Medicaid Non-Managed Care-Penalty/Payback (c4)',
#        'Medicaid Non-Managed Care-Adjustments (d)',
#        'Medicaid Managed Care (capitated)-Full Charges This Period (a)',
#        ...
#        'Self-Pay-Bad Debt Write-Off (f)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Full Charges This Period (a)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Amount Collected This Period (b)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Collection of Reconciliation/Wraparound Current Year (c1)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Collection of Reconciliation/Wraparound Previous Years (c2)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Collection of Other Payments: P4P, Risk Pools, etc. (c3)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Penalty/Payback (c4)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Adjustments (d)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Sliding Fee Discounts (e)',
#        'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Bad Debt Write-Off (f)'],
#       dtype='object', length=124)
#
# -----------------------------------
# The personnel_and_visits dataframe has a shape of (1370, 176).
#
# The personnel_and_visits dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', 'Family Physicians-FTEs (a)',
#        'Family Physicians-Clinic Visits (b)',
#        'Family Physicians-Virtual Visits (b2)',
#        'General Practitioners-FTEs (a)',
#        'General Practitioners-Clinic Visits (b)',
#        'General Practitioners-Virtual Visits (b2)', 'Internists-FTEs (a)',
#        'Internists-Clinic Visits (b)',
#        ...
#        'Licensed Clinical Psychologists-Virtual Visits (b2)',
#        'Licensed Clinical Psychologists-Patients (c)',
#        'Licensed Clinical Social Workers-Personnel (a1)',
#        'Licensed Clinical Social Workers-Clinic Visits (b)',
#        'Licensed Clinical Social Workers-Virtual Visits (b2)',
#        'Licensed Clinical Social Workers-Patients (c)',
#        'Other Licensed Mental Health Providers-Personnel (a1)',
#        'Other Licensed Mental Health Providers-Clinic Visits (b)',
#        'Other Licensed Mental Health Providers-Virtual Visits (b2)',
#        'Other Licensed Mental Health Providers-Patients (c)'],
#       dtype='object', length=176)
#
# -----------------------------------
# The patients_age dataframe has a shape of (1370, 80).
#
# The patients_age dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', 'Under age 1-Male Patients (a)',
#        'Under age 1-Female Patients (b)', 'Age 1-Male Patients (a)',
#        'Age 1-Female Patients (b)', 'Age 2-Male Patients (a)',
#        'Age 2-Female Patients (b)', 'Age 3-Male Patients (a)',
#        'Age 3-Female Patients (b)', 'Age 4-Male Patients (a)',
#        'Age 4-Female Patients (b)', 'Age 5-Male Patients (a)',
#        'Age 5-Female Patients (b)', 'Age 6-Male Patients (a)',
#        'Age 6-Female Patients (b)', 'Age 7-Male Patients (a)',
#        'Age 7-Female Patients (b)', 'Age 8-Male Patients (a)',
#        'Age 8-Female Patients (b)', 'Age 9-Male Patients (a)',
#        'Age 9-Female Patients (b)', 'Age 10-Male Patients (a)',
#        'Age 10-Female Patients (b)', 'Age 11-Male Patients (a)',
#        'Age 11-Female Patients (b)', 'Age 12-Male Patients (a)',
#        'Age 12-Female Patients (b)', 'Age 13-Male Patients (a)',
#        'Age 13-Female Patients (b)', 'Age 14-Male Patients (a)',
#        'Age 14-Female Patients (b)', 'Age 15-Male Patients (a)',
#        'Age 15-Female Patients (b)', 'Age 16-Male Patients (a)',
#        'Age 16-Female Patients (b)', 'Age 17-Male Patients (a)',
#        'Age 17-Female Patients (b)', 'Age 18-Male Patients (a)',
#        'Age 18-Female Patients (b)', 'Age 19-Male Patients (a)',
#        'Age 19-Female Patients (b)', 'Age 20-Male Patients (a)',
#        'Age 20-Female Patients (b)', 'Age 21-Male Patients (a)',
#        'Age 21-Female Patients (b)', 'Age 22-Male Patients (a)',
#        'Age 22-Female Patients (b)', 'Age 23-Male Patients (a)',
#        'Age 23-Female Patients (b)', 'Age 24-Male Patients (a)',
#        'Age 24-Female Patients (b)', 'Ages 25–29-Male Patients (a)',
#        'Ages 25–29-Female Patients (b)', 'Ages 30–34-Male Patients (a)',
#        'Ages 30–34-Female Patients (b)', 'Ages 35–39-Male Patients (a)',
#        'Ages 35–39-Female Patients (b)', 'Ages 40–44-Male Patients (a)',
#        'Ages 40–44-Female Patients (b)', 'Ages 45–49-Male Patients (a)',
#        'Ages 45–49-Female Patients (b)', 'Ages 50–54-Male Patients (a)',
#        'Ages 50–54-Female Patients (b)', 'Ages 55–59-Male Patients (a)',
#        'Ages 55–59-Female Patients (b)', 'Ages 60–64-Male Patients (a)',
#        'Ages 60–64-Female Patients (b)', 'Ages 65–69-Male Patients (a)',
#        'Ages 65–69-Female Patients (b)', 'Ages 70–74-Male Patients (a)',
#        'Ages 70–74-Female Patients (b)', 'Ages 75–79-Male Patients (a)',
#        'Ages 75–79-Female Patients (b)', 'Ages 80–84-Male Patients (a)',
#        'Ages 80–84-Female Patients (b)', 'Age 85 and over-Male Patients (a)',
#        'Age 85 and over-Female Patients (b)',
#        'Total Patients (Sum of Lines 1-38)-Male Patients (a)',
#        'Total Patients (Sum of Lines 1-38)-Female Patients (b)'],
#       dtype='object')
#
# -----------------------------------
# The patients_race dataframe has a shape of (1370, 51).
#
# The patients_race dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', 'Asian-Hispanic or Latino/a (a)',
#        'Asian-Non-Hispanic or Latino/a (b)',
#        'Asian-Total (d) (Sum Columns a+b+c)',
#        'Native Hawaiian-Hispanic or Latino/a (a)',
#        'Native Hawaiian-Non-Hispanic or Latino/a (b)',
#        'Native Hawaiian-Total (d) (Sum Columns a+b+c)',
#        'Other Pacific Islander-Hispanic or Latino/a (a)',
#        'Other Pacific Islander-Non-Hispanic or Latino/a (b)',
#        'Other Pacific Islander-Total (d) (Sum Columns a+b+c)',
#        'Total Native Hawaiian/Other Pacific Islander (Sum Lines 2a + 2b)-Hispanic or Latino/a (a)',
#        'Total Native Hawaiian/Other Pacific Islander (Sum Lines 2a + 2b)-Non-Hispanic or Latino/a (b)',
#        'Total Native Hawaiian/Other Pacific Islander (Sum Lines 2a + 2b)-Total (d) (Sum Columns a+b+c)',
#        'Black/African American-Hispanic or Latino/a (a)',
#        'Black/African American-Non-Hispanic or Latino/a (b)',
#        'Black/African American-Total (d) (Sum Columns a+b+c)',
#        'American Indian/Alaska Native-Hispanic or Latino/a (a)',
#        'American Indian/Alaska Native-Non-Hispanic or Latino/a (b)',
#        'American Indian/Alaska Native-Total (d) (Sum Columns a+b+c)',
#        'White-Hispanic or Latino/a (a)', 'White-Non-Hispanic or Latino/a (b)',
#        'White-Total (d) (Sum Columns a+b+c)',
#        'More than one race-Hispanic or Latino/a (a)',
#        'More than one race-Non-Hispanic or Latino/a (b)',
#        'More than one race-Total (d) (Sum Columns a+b+c)',
#        'Unreported/Chose Not to Disclose race-Hispanic or Latino/a (a)',
#        'Unreported/Chose Not to Disclose race-Non-Hispanic or Latino/a (b)',
#        'Unreported/Chose Not to Disclose race-Unreported/Chose Not to Disclose Ethnicity (c)',
#        'Unreported/Chose Not to Disclose race-Total (d) (Sum Columns a+b+c)',
#        'Total Patients (Sum of Lines 1 + 2 + 3 to 7)-Hispanic or Latino/a (a)',
#        'Total Patients (Sum of Lines 1 + 2 + 3 to 7)-Non-Hispanic or Latino/a (b)',
#        'Total Patients (Sum of Lines 1 + 2 + 3 to 7)-Unreported/Chose Not to Disclose Ethnicity (c)',
#        'Total Patients (Sum of Lines 1 + 2 + 3 to 7)-Total (d) (Sum Columns a+b+c)',
#        'Patients Best Served in a Language Other than English-Number (a)',
#        'Lesbian or Gay-Number (a)', 'Heterosexual (or straight)-Number (a)',
#        'Bisexual-Number (a)', 'Other-Number (a)', 'Don’t know-Number (a)',
#        'Chose not to disclose-Number (a)', 'Unknown-Number (a)',
#        'Total Patients (Sum of Lines 13 to 18a)-Number (a)', 'Male-Number (a)',
#        'Female-Number (a)',
#        'Transgender Man/Transgender Male/Transmasculine-Number (a)',
#        'Transgender Woman/Transgender Female/Transfeminine-Number (a)',
#        'Other-Number (a)', 'Chose not to disclose-Number (a)',
#        'Unknown-Number (a)',
#        'Total Patients (Sum of Lines 20 to 25a)-Number (a)'],
#       dtype='object')
#
# -----------------------------------
# The patients_other_demographics dataframe has a shape of (1370, 60).
#
# The patients_other_demographics dataframe has the following columns and number of values:
# Index(['BHCMISID', 'GrantNumber', '100% and below-Number of Patients (a)',
#        '101–150%-Number of Patients (a)', '151–200%-Number of Patients (a)',
#        'Over 200%-Number of Patients (a)', 'Unknown-Number of Patients (a)',
#        'TOTAL (Sum of Lines 1–5)-Number of Patients (a)',
#        'None/Uninsured-0-17 years old (a)', 'None/Uninsured-18 and older (b)',
#        'Medicaid (Title XIX)-0-17 years old (a)',
#        'Medicaid (Title XIX)-18 and older (b)',
#        'CHIP Medicaid-0-17 years old (a)', 'CHIP Medicaid-18 and older (b)',
#        'Total Medicaid (Line 8a + 8b)-0-17 years old (a)',
#        'Total Medicaid (Line 8a + 8b)-18 and older (b)',
#        'Dually Eligible (Medicare and Medicaid)-0-17 years old (a)',
#        'Dually Eligible (Medicare and Medicaid)-18 and older (b)',
#        'Medicare (Inclusive of dually eligible and other Title XVIII beneficiaries)-0-17 years old (a)',
#        'Medicare (Inclusive of dually eligible and other Title XVIII beneficiaries)-18 and older (b)',
#        'Other Public Insurance (Non-CHIP)-Others',
#        'Other Public Insurance (Non-CHIP)-0-17 years old (a)',
#        'Other Public Insurance (Non-CHIP)-18 and older (b)',
#        'Other Public Insurance CHIP-0-17 years old (a)',
#        'Other Public Insurance CHIP-18 and older (b)',
#        'Total Public Insurance (Line 10a + 10b)-0-17 years old (a)',
#        'Total Public Insurance (Line 10a + 10b)-18 and older (b)',
#        'Private Insurance-0-17 years old (a)',
#        'Private Insurance-18 and older (b)',
#        'TOTAL (Sum of Lines 7 + 8 + 9 +10 +11)-0-17 years old (a)',
#        'TOTAL (Sum of Lines 7 + 8 + 9 +10 +11)-18 and older (b)',
#        'Capitated Member Months-Medicaid (a)',
#        'Capitated Member Months-Medicare (b)',
#        'Capitated Member Months-Other Public Including Non-Medicaid CHIP (c)',
#        'Capitated Member Months-Private (d)',
#        'Capitated Member Months-TOTAL (e)',
#        'Fee-for-service Member Months-Medicaid (a)',
#        'Fee-for-service Member Months-Medicare (b)',
#        'Fee-for-service Member Months-Other Public Including Non-Medicaid CHIP (c)',
#        'Fee-for-service Member Months-Private (d)',
#        'Fee-for-service Member Months-TOTAL (e)',
#        'Total Member Months (Sum of Lines 13a + 13b)-Medicaid (a)',
#        'Total Member Months (Sum of Lines 13a + 13b)-Medicare (b)',
#        'Total Member Months (Sum of Lines 13a + 13b)-Other Public Including Non-Medicaid CHIP (c)',
#        'Total Member Months (Sum of Lines 13a + 13b)-Private (d)',
#        'Total Member Months (Sum of Lines 13a + 13b)-TOTAL (e)',
#        'Migratory (330g awardees only)-Number of Patients (a)',
#        'Seasonal (330g awardees only)-Number of Patients (a)',
#        'Total Agricultural Workers or Dependents (All health centers report this line)-Number of Patients (a)',
#        'Homeless Shelter (330h awardees only)-Number of Patients (a)',
#        'Transitional (330h awardees only)-Number of Patients (a)',
#        'Doubling Up (330h awardees only)-Number of Patients (a)',
#        'Street (330h awardees only)-Number of Patients (a)',
#        'Permanent Supportive Housing (330h awardees only)-Number of Patients (a)',
#        'Other (330h awardees only)-Number of Patients (a)',
#        'Unknown (330h awardees only)-Number of Patients (a)',
#        'Total Homeless (All health centers report this line)-Number of Patients (a)',
#        'Total School-Based Service Site Patients (All health centers report this line)-Number of Patients (a)',
#        'Total Veterans (All health centers report this line)-Number of Patients (a)',
#        'Total Patients Served at a Health Center Located In or Immediately Accessible to a Public Housing Site (All health centers report this line)-Number of Patients (a)'],
#       dtype='object')
#
# -----------------------------------

# %% [markdown]
# ## Subsetting dataframes before further cleaning and EDA
#
# There is a lot of useful data across these dataframes, however, I will not be able to keep all of these columns for my analysis and model development. Below I will be subsetting each dataframe to keep core components of each one. I'll provide justification as to why I am removing or keeping certain columns.
#
# In general, I will be keeping the `BHCMISID` and the `GrantNumber` columns because this will allow me to know which records pertain to the unique health center / entity.
#
# I will not make any changes at this point to the health_center_zipcodes df.

# %% [markdown]
# ### Subsetting the `health_centers` df
#
# I'll remove the address columns and the information about the project director. Knowing the city, state, and zip codes might provide  interesting information for analysis, especially to group by specific geographical regions. The address of the orgnaizations will not provide useful information for the scope of this project. Similarly, knowing who the project director is will not benefit further analysis for this project.
#
# Health Centers can receive funding for special populations, as defined by HRSA, in addition to Health Center Program funding. `FundingCHC` represents the Health Center Program funding that is not for any specific population group. There are three types of special population funding:
# 1. Migrant Health Center Funding - represented by the `FundingMHC` column
# 2. Health Center funding for Homeless - represented by the `FundingHO` column
# 3. Public Housing Primary Care Funding - represented by the `FundingPH` column
#
# Looking at how the various sub-funding types influence overall funding will be interesting for further analysis. Also, I will keep the `UrbanRuralFlag` column as their primary designation will offer interesting insights too.

# %%
# drop columns from health_centers df
health_centers_1 = health_centers.drop(columns=['ReportingYear', 'HealthCenterStreetAddress', 'HealthCenterOtherAddress', 
                                                'ProjectDirector', 'ProjectDirectorPhone', 'ProjectDirectorPhoneExt', 
                                                'ProjectDirectorFax', 'ProjectDirectorEmail'])

# %% [markdown]
# ### Subsetting the `health_center_sites` df
#
# Health Centers have to report information about their approved sites, which include service location sites and administrative sites. I  want to understand how things like the total number of sites per organization, operating hours, population type (urbarn/rural) for each site, and site geographical factors influence funding. All other columns will be removed for analysis.

# %%
# subset health_center_sites df
health_center_sites_1 = health_center_sites[['BHCMISID', 'GrantNumber', 'SiteName', 'SiteType', 'SiteStatus', 
                                             'LocationType','TotalWeeklyHoursOfOperation', 'ServiceAreaPopulation', 
                                             'SiteOperatedBy', 'SiteCity', 'SiteState', 'SiteZIPCode']]

# %% [markdown]
# ### Subsetting the `health_center_funding` df
#
# I want to know how much Health Center Program funding each entity receives, and the amounts they receive for special populations (MHC, HO, and PH funding). Other Bureau of Primary Health Care grant details will not be necessary, but I will preserve the column that sums up the total BPHC funding each entity receives `Total BPHC Grants`. Note that a lot of this funding was expanded due to the COVID pandemic and will likely not occur in future years. Most federal COVID funding will expire by the end of September 2024.
#
# It will be interesting to compare the CHC funding to each organization's total revenue as well as other government and non-government grant revenue. I'll preserve the appropriate columns. I will not need to know the specific sources of other revenue for the scope of this project, for example, which foundation an organization might receive grants from.
#
# Also, many of these columns have long names, I'll rename them for easier processing.

# %%
# subset health_center_funding df
health_center_funding_1 = health_center_funding[['BHCMISID', 'GrantNumber', 'Migrant Health Center-Amount (a)', 
                                                 'Community Health Center-Amount (a)', 'Health Care for the Homeless-Amount (a)',
                                                 'Public Housing Primary Care-Amount (a)', 'Total Health Center (Sum of Lines 1a through 1e)-Amount (a)',
                                                 'Total BPHC Grants (Sum of Lines 1g + 1k + 1q)-Amount (a)', 'Other Federal Grants-Amount (a)',
                                                 'State Government Grants and Contracts-Amount (a)', 'Foundation/Private Grants and Contracts-Amount (a)',
                                                 'Other Revenue (non-patient service revenue not reported elsewhere)-Amount (a)', 
                                                 'Total Revenue (Sum of Lines 1 + 5 + 9 + 10)-Amount (a)']]

# %%
# rename health_center_funding_1 columns
health_center_funding_1 = health_center_funding_1.rename(columns={'Migrant Health Center-Amount (a)':'mhc_amount', 
                                        'Community Health Center-Amount (a)':'chc_amount', 
                                        'Health Care for the Homeless-Amount (a)':'ho_amount',
                                        'Public Housing Primary Care-Amount (a)':'ph_amount', 
                                        'Total Health Center (Sum of Lines 1a through 1e)-Amount (a)':'total_hc_funding',
                                        'Total BPHC Grants (Sum of Lines 1g + 1k + 1q)-Amount (a)':'bphc_total', 
                                        'Other Federal Grants-Amount (a)':'total_other_federal_grants',
                                        'State Government Grants and Contracts-Amount (a)':'total_state_grants', 
                                        'Foundation/Private Grants and Contracts-Amount (a)':'total_private_grants',
                                        'Other Revenue (non-patient service revenue not reported elsewhere)-Amount (a)':'total_other_revenue', 
                                        'Total Revenue (Sum of Lines 1 + 5 + 9 + 10)-Amount (a)':'total_revenue'})

# %% [markdown]
# ### Subsetting the `health_center_costs` df
#
# Similar to the personnel and visits dataframe, I will subset the costs of providing care by the four core service types: medical care, dental care, mental health care, and enabling services. I will also include the costs for quality improvement initiatives because I am curious if this type of programming has any impact on overall funding an entity receives. [HRSA requires](https://bphc.hrsa.gov/compliance/compliance-manual/chapter10) health center grantees to create an annual quality management and improvement plans that "support the quality assurance program and the provision of high quality patient care".
#
# I have chosen the columns that reflect the total cost including administrative and operational costs such as facilities and non-clinical staff to get the true cost of providing care in these categories.
#
# I'll rename these columns for readability.

# %%
health_center_costs_1 = health_center_costs[['BHCMISID',
                                             'GrantNumber',
                                             'Total Medical Care Services (Sum of Lines 1 through 3)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
                                             'Dental-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
                                             'Mental Health-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
                                             'Total Enabling Services (Sum of Lines 11a through 11h)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
                                             'Quality Improvement-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)',
                                             'Total Accrued Costs (Sum of Lines 4 + 10 + 13 + 16)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)']]

# %%
health_center_costs_1 = health_center_costs_1.rename(columns={
                                             'Total Medical Care Services (Sum of Lines 1 through 3)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)':'total_costs_medical',
                                             'Dental-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)':'total_costs_dental',
                                             'Mental Health-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)':'total_costs_mh',
                                             'Total Enabling Services (Sum of Lines 11a through 11h)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)':'total_costs_enabling',
                                             'Quality Improvement-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)':'total_costs_quality',
                                             'Total Accrued Costs (Sum of Lines 4 + 10 + 13 + 16)-Total Cost After Allocation of Facility and Non-Clinical Support Services (c)':'total_cost_care'})

# %% [markdown]
# ### Subsetting the `personnel_and_visits` df
# Although health centers provide a range of healthcare and support services, the most common that organizations provide are medical care, dental care, mental health care, and enabling services. Becuase of this, I will be excluding other types of specialty care from the personnel and visits dataframe. Examples of these services include substance use disorder care, psychiatry, vision, etc.
#
# I will preserve total clinic and virtual visits which includes other visit types to get a full picture of how many clinic and virtual visits entities provided in 2022.
#
# Several columns from this table are also long, so I will rename them for readability.

# %%
# subset personnel_and_visits df
personnel_and_visits_1 = personnel_and_visits[['BHCMISID', 'GrantNumber', 
                                               'Total Medical Care Services (Lines 8 + 10a through 14)-Clinic Visits (b)',
                                               'Total Medical Care Services (Lines 8 + 10a through 14)-Virtual Visits (b2)',
                                               'Total Medical Care Services (Lines 8 + 10a through 14)-Patients (c)',
                                               'Total Dental Services (Lines 16–18)-Clinic Visits (b)',
                                               'Total Dental Services (Lines 16–18)-Virtual Visits (b2)',
                                               'Total Dental Services (Lines 16–18)-Patients (c)',
                                               'Total Mental Health Services (Lines 20a-c)-Clinic Visits (b)',
                                               'Total Mental Health Services (Lines 20a-c)-Virtual Visits (b2)',
                                               'Total Mental Health Services (Lines 20a-c)-Patients (c)',
                                               'Total Enabling Services (Lines 24–28)-Clinic Visits (b)',
                                               'Total Enabling Services (Lines 24–28)-Virtual Visits (b2)',
                                               'Total Enabling Services (Lines 24–28)-Patients (c)',
                                               'Grand Total (Lines 15+19+20+21+22+22d+23+29+29a+29b+33)-Clinic Visits (b)',
                                               'Grand Total (Lines 15+19+20+21+22+22d+23+29+29a+29b+33)-Virtual Visits (b2)']]

# %%
#rename personnel_and_visits_1 columns
personnel_and_visits_1 = personnel_and_visits_1.rename(columns={
                                               'Total Medical Care Services (Lines 8 + 10a through 14)-Clinic Visits (b)':'medical_clinic_visits',
                                               'Total Medical Care Services (Lines 8 + 10a through 14)-Virtual Visits (b2)':'medical_virtual_visits',
                                               'Total Medical Care Services (Lines 8 + 10a through 14)-Patients (c)':'medical_patients',
                                               'Total Dental Services (Lines 16–18)-Clinic Visits (b)':'dental_clinic_visits',
                                               'Total Dental Services (Lines 16–18)-Virtual Visits (b2)':'dental_virtual_visits',
                                               'Total Dental Services (Lines 16–18)-Patients (c)':'dental_patients',
                                               'Total Mental Health Services (Lines 20a-c)-Clinic Visits (b)':'mh_clinic_visits',
                                               'Total Mental Health Services (Lines 20a-c)-Virtual Visits (b2)':'mh_virtual_visits',
                                               'Total Mental Health Services (Lines 20a-c)-Patients (c)':'mh_patients',
                                               'Total Enabling Services (Lines 24–28)-Clinic Visits (b)':'enabling_clinic_visits',
                                               'Total Enabling Services (Lines 24–28)-Virtual Visits (b2)':'enabling_virtual_visits',
                                               'Total Enabling Services (Lines 24–28)-Patients (c)':'enabling_patients',
                                               'Grand Total (Lines 15+19+20+21+22+22d+23+29+29a+29b+33)-Clinic Visits (b)':'total_clinic_visits',
                                               'Grand Total (Lines 15+19+20+21+22+22d+23+29+29a+29b+33)-Virtual Visits (b2)':'total_virtual_visits'})

# %% [markdown]
# ### Subsetting the `patient_services_revenue` df
#
# I won't be using most of the columns from this dataframe becauase they have to do with Medicaid (MA) and Medicare (MC) reimbursement rates. MA and MC reimbursement rates can vary drastically across different geographical regions, primarily due to the volume of services delivered. According to [Dartmouth's Atlas Project](https://www.dartmouthatlas.org/interactive-apps/medicare-reimbursements/), among over 300 hospital referral regions in the U.S., price-adjusted MC reimbursements varied from 8,273 USD to 14,351 USD in 2019.
#
# I'll preserve the total charges for each entity in 2022 and the total amount each entity collected. I will also keep the sliding fee scale discounts. SFS programs are a core operational compoenent of FQHCs as it ensures that services are provied based on patient income. The main purpose of the health center program funding is to offset losses experienced by entities for having an SFS program.

# %%
patient_services_revenue_1 = patient_services_revenue[['BHCMISID', 'GrantNumber', 
                                                       'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Full Charges This Period (a)',
                                                       'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Amount Collected This Period (b)',
                                                       'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Sliding Fee Discounts (e)']]

# %%
patient_services_revenue_1 = patient_services_revenue_1.rename(columns={ 
                                                       'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Full Charges This Period (a)':'total_charges',
                                                       'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Amount Collected This Period (b)':'total_collected',
                                                       'TOTAL (Sum of Lines 3 + 6 + 9 + 12 + 13)-Sliding Fee Discounts (e)':'total_sfs'})

# %% [markdown]
# ### Subsetting the `patients_age` df
#
# I only want to keep the total male and total female patients to combine these totals into a new column to capture a new column for total patients per entity.

# %%
patients_age_1 = patients_age[['BHCMISID', 'GrantNumber', 'Total Patients (Sum of Lines 1-38)-Male Patients (a)',
                               'Total Patients (Sum of Lines 1-38)-Female Patients (b)']]

# %%
patients_age_1 = patients_age_1.rename(columns={'Total Patients (Sum of Lines 1-38)-Male Patients (a)':'total_male',
                               'Total Patients (Sum of Lines 1-38)-Female Patients (b)':'total_female'})

# %% [markdown]
# ### Subsetting the `patients_other_demographics` df
#
# After reviewing the columns for this df, I realize I don't need to use the `patients_age` df to capture total patients as that will be captured in the `patients_other_demographics` df.
#
# Of the `patients_other_demographics` df, I will keep details about the number of patients within various federal poverty level categories. I will also keep details about general insurance coverage (MA, MC, Other Public, Private) and special populations served.

# %%
patients_other_demographics_1 = patients_other_demographics[['BHCMISID', 'GrantNumber', '100% and below-Number of Patients (a)',
                                                                '101–150%-Number of Patients (a)', '151–200%-Number of Patients (a)',
                                                                'Over 200%-Number of Patients (a)', 'Unknown-Number of Patients (a)',
                                                                'TOTAL (Sum of Lines 1–5)-Number of Patients (a)', 
                                                                'None/Uninsured-0-17 years old (a)', 'None/Uninsured-18 and older (b)', 
                                                                'Total Medicaid (Line 8a + 8b)-0-17 years old (a)',
                                                                'Total Medicaid (Line 8a + 8b)-18 and older (b)',
                                                                'Medicare (Inclusive of dually eligible and other Title XVIII beneficiaries)-18 and older (b)',
                                                                'Total Public Insurance (Line 10a + 10b)-0-17 years old (a)',
                                                                'Total Public Insurance (Line 10a + 10b)-18 and older (b)',
                                                                'Private Insurance-0-17 years old (a)',
                                                                'Private Insurance-18 and older (b)',
                                                                'TOTAL (Sum of Lines 7 + 8 + 9 +10 +11)-0-17 years old (a)',
                                                                'TOTAL (Sum of Lines 7 + 8 + 9 +10 +11)-18 and older (b)',
                                                                'Total Agricultural Workers or Dependents (All health centers report this line)-Number of Patients (a)',
                                                                'Total Homeless (All health centers report this line)-Number of Patients (a)',
                                                                'Total School-Based Service Site Patients (All health centers report this line)-Number of Patients (a)',
                                                                'Total Veterans (All health centers report this line)-Number of Patients (a)',
                                                                'Total Patients Served at a Health Center Located In or Immediately Accessible to a Public Housing Site (All health centers report this line)-Number of Patients (a)']]

# %%
patients_other_demographics_1 = patients_other_demographics_1.rename(columns={'100% and below-Number of Patients (a)':'fpl_100_below',
                                                                              '101–150%-Number of Patients (a)':'fpl_101_to_150',
                                                                              '151–200%-Number of Patients (a)':'fpl_151_to_200',
                                                                              'Over 200%-Number of Patients (a)':'fpl_over_200', 
                                                                              'Unknown-Number of Patients (a)':'fpl_unknown',
                                                                              'TOTAL (Sum of Lines 1–5)-Number of Patients (a)':'total_patients', 
                                                                              'None/Uninsured-0-17 years old (a)':'uninsured_0_17', 
                                                                              'None/Uninsured-18 and older (b)':'uninsured_18_up', 
                                                                              'Total Medicaid (Line 8a + 8b)-0-17 years old (a)':'medicaid_0_17',
                                                                              'Total Medicaid (Line 8a + 8b)-18 and older (b)':'medicaid_18_up',
                                                                              'Medicare (Inclusive of dually eligible and other Title XVIII beneficiaries)-18 and older (b)':'medicare_18_up',
                                                                              'Total Public Insurance (Line 10a + 10b)-0-17 years old (a)':'public_insurance_0_17',
                                                                              'Total Public Insurance (Line 10a + 10b)-18 and older (b)':'public_insurance_18_up',
                                                                              'Private Insurance-0-17 years old (a)':'private_insurance_0_17',
                                                                              'Private Insurance-18 and older (b)':'private_insurance_18_up',
                                                                              'TOTAL (Sum of Lines 7 + 8 + 9 +10 +11)-0-17 years old (a)':'total_0_17',
                                                                              'TOTAL (Sum of Lines 7 + 8 + 9 +10 +11)-18 and older (b)':'total_18_up',
                                                                              'Total Agricultural Workers or Dependents (All health centers report this line)-Number of Patients (a)':'migrant_patients',
                                                                              'Total Homeless (All health centers report this line)-Number of Patients (a)':'homeless_patients',
                                                                              'Total School-Based Service Site Patients (All health centers report this line)-Number of Patients (a)':'school_based_patients',
                                                                              'Total Veterans (All health centers report this line)-Number of Patients (a)':'veteran_patients',
                                                                              'Total Patients Served at a Health Center Located In or Immediately Accessible to a Public Housing Site (All health centers report this line)-Number of Patients (a)':'public_housing_patients'})

# %% [markdown]
# ### Subsetting the `paitents_race` df
#
# FQHCs aim to provide care to underserved communities in the United States. Due to systemic racism and discriminations, individuals of color are less likely to have access to quality health care due to various social determinants of health (transportation, financial barriers, language barriers, etc.). Understanding the racial and ethnic distribution of patients across entities may be an important factor in the level of funding they receive through the Health Center Program.
#
# I'll simplify this table by only keeping the race-alone categories (ex: Asian Non-Hispanic individuals) and all Hispanic patients regardless of race. I will also keep the patients who face language barriers to see if this factor has a significant effect.

# %%
patients_race_1 = patients_race[['BHCMISID', 
                                 'GrantNumber', 
                                 'Asian-Non-Hispanic or Latino/a (b)',
                                 'Native Hawaiian-Non-Hispanic or Latino/a (b)',
                                 'Other Pacific Islander-Non-Hispanic or Latino/a (b)',
                                 'Black/African American-Non-Hispanic or Latino/a (b)',
                                 'American Indian/Alaska Native-Non-Hispanic or Latino/a (b)',
                                 'White-Non-Hispanic or Latino/a (b)',
                                 'Unreported/Chose Not to Disclose race-Unreported/Chose Not to Disclose Ethnicity (c)',
                                 'Total Patients (Sum of Lines 1 + 2 + 3 to 7)-Hispanic or Latino/a (a)',
                                 'Total Patients (Sum of Lines 1 + 2 + 3 to 7)-Total (d) (Sum Columns a+b+c)',
                                 'Patients Best Served in a Language Other than English-Number (a)']]

# %%
patients_race_1 = patients_race_1.rename(columns={ 
                                 'Asian-Non-Hispanic or Latino/a (b)':'asian',
                                 'Native Hawaiian-Non-Hispanic or Latino/a (b)':'native_hawaiian',
                                 'Other Pacific Islander-Non-Hispanic or Latino/a (b)':'pac_isl',
                                 'Black/African American-Non-Hispanic or Latino/a (b)':'black',
                                 'American Indian/Alaska Native-Non-Hispanic or Latino/a (b)':'am_ind',
                                 'White-Non-Hispanic or Latino/a (b)':'white',
                                 'Unreported/Chose Not to Disclose race-Unreported/Chose Not to Disclose Ethnicity (c)':'unreported',
                                 'Total Patients (Sum of Lines 1 + 2 + 3 to 7)-Hispanic or Latino/a (a)':'hispanic_any_race',
                                 'Total Patients (Sum of Lines 1 + 2 + 3 to 7)-Total (d) (Sum Columns a+b+c)':'total_patients',
                                 'Patients Best Served in a Language Other than English-Number (a)':'lep_patients'})

# %% [markdown]
# # Handling Missing Values
#
# I mentioned earlier that there are three main types of missing values in this dataset. However, running `.isnull().sum()` won't be informative because of how they are represented.
#
# **Missing Values Representation**
# 1. "-" represents no data entry by health center
# 2. "--" represents suppressed patient counts between 1-15 to protect patient privacy
# 3. "---" represents suppressed health center confidential data
#
# I'll handle each of these null values differently since they have different meanings.
# 1. I will replace the '-' with 0 because these represent no data entry by the health center for those fields. For this specific dataset, 0 is a base number so it will not be misleading for the model(s).
# 2. I'll start by replacing the '---' with NaN values to determine the scope of these types of missing values. Depending how how many are missing from the various dataframes, I will either handle them by dropping samples, replacing them with mean or median, KNN, MICE, or other methods.
# 3. For the '--', these missing values actually have at least 1 and at max 15 counts. The data has been repressed for privacy.

# %%
new_df_dict = {'health_centers': health_centers_1, 
              'health_center_sites': health_center_sites_1, 
              'health_center_funding': health_center_funding_1, 
              'health_center_zipcodes': health_center_zipcodes,
              'health_center_costs': health_center_costs_1,
              'patient_services_revenue': patient_services_revenue_1, 
              'personnel_and_visits': personnel_and_visits_1, 
              'patients_race': patients_race_1, 
              'patients_other_demographics': patients_other_demographics_1}

# %%
"""def find_missing_values(df_dictionary, key, missing_variable):

    '''Find the counts for an unusual missing variable type.
    
    Arugments:
    1. A dictionary of dataframes.
    2. A key for the dataframe names.
    3. The missing variable you want to count.'''

    # establish the df from the df_dict and key
    df = df_dictionary[key]

    print(f'The {key} dataframe has the following missing value counts for "{missing_variable}": ')
    print()
    
    #check for missing values in each column
    missing_values = df.apply(lambda x: (x == missing_variable).sum())
    
    # dispaly the missing values information
    missing_values_df = pd.DataFrame(missing_values, columns=['Missing Values'])
    missing_values_df['% of Total'] = (missing_values_df['Missing Values'] / len(df)) * 100
    missing_values_df = missing_values_df.sort_values(by='Missing Values', ascending=False)

    print(missing_values_df)"""
# Out:
# 'def find_missing_values(df_dictionary, key, missing_variable):\n\n    \'\'\'Find the counts for an unusual missing variable type.\n    \n    Arugments:\n    1. A dictionary of dataframes.\n    2. A key for the dataframe names.\n    3. The missing variable you want to count.\'\'\'\n\n    # establish the df from the df_dict and key\n    df = df_dictionary[key]\n\n    print(f\'The {key} dataframe has the following missing value counts for "{missing_variable}": \')\n    print()\n    \n    #check for missing values in each column\n    missing_values = df.apply(lambda x: (x == missing_variable).sum())\n    \n    # dispaly the missing values information\n    missing_values_df = pd.DataFrame(missing_values, columns=[\'Missing Values\'])\n    missing_values_df[\'% of Total\'] = (missing_values_df[\'Missing Values\'] / len(df)) * 100\n    missing_values_df = missing_values_df.sort_values(by=\'Missing Values\', ascending=False)\n\n    print(missing_values_df)'

# %%
def find_missing_values(df_dictionary, key, missing_variable):

    '''Find the counts for an unusual missing variable type.
    
    Arugments:
    1. A dictionary of dataframes.
    2. A key for the dataframe names.
    3. The missing variable you want to count.'''

    # establish the df from the df_dict and key
    df = df_dictionary[key]
   
    missing_values = {}

    for col in df.columns:
        count = (df[col] == missing_variable).sum()
        if count > 0:
            missing_values[col] = count
    
    if not missing_values:
        print(f'The {key} does not contain any instances of {missing_variable}.')
        print()

    else:
        missing_values_df = pd.DataFrame.from_dict(missing_values, orient='index').reset_index()
        missing_values_df.columns = ['Column Name', 'Missing Value Count']
        missing_values_df['% of Total'] = (missing_values_df['Missing Value Count'] / len(df)) * 100
        missing_values['% of Total'] = missing_values_df['% of Total'].round(4)
        missing_values_df = missing_values_df.sort_values(by='Missing Value Count', ascending=False)
    
        print(f'The {key} dataframe has the following missing value counts for "{missing_variable}": ')
        print()
        
        print(missing_values_df)
        print()

# %%
for key in new_df_dict.keys():
    find_missing_values(new_df_dict, key, '-')
# Out:
# The health_centers dataframe has the following missing value counts for "-":
#
#            Column Name  Missing Value Count  % of Total
# 0  HealthCenterZIPCode                    1    0.072993
#
# The health_center_sites dataframe has the following missing value counts for "-":
#
#                    Column Name  Missing Value Count  % of Total
# 4                  SiteZIPCode                 1400    9.341429
# 1  TotalWeeklyHoursOfOperation                   17    0.113432
# 2                     SiteCity                    3    0.020017
# 0                     SiteName                    2    0.013345
# 3                    SiteState                    2    0.013345
#
# The health_center_funding dataframe has the following missing value counts for "-":
#
#                   Column Name  Missing Value Count  % of Total
# 3                   ph_amount                  710   51.824818
# 0                  mhc_amount                  648   47.299270
# 2                   ho_amount                  603   44.014599
# 4  total_other_federal_grants                  494   36.058394
# 5          total_state_grants                  257   18.759124
# 6        total_private_grants                  175   12.773723
# 7         total_other_revenue                  159   11.605839
# 1                  chc_amount                   39    2.846715
#
# The health_center_zipcodes dataframe has the following missing value counts for "-":
#
#                          Column Name  Missing Value Count  % of Total
# 3                   MedicarePatients                 3781    3.892240
# 4                    PrivatePatients                 2906    2.991497
# 0                            ZipCode                 2740    2.820613
# 1             None_UninsuredPatients                 2350    2.419139
# 2  Medicaid_CHIP_OtherPublicPatients                 1889    1.944576
# 5              TotalNumberofPatients                  519    0.534269
#
# The health_center_costs dataframe has the following missing value counts for "-":
#
#             Column Name  Missing Value Count  % of Total
# 0    total_costs_dental                   45    3.284672
# 3   total_costs_quality                   29    2.116788
# 2  total_costs_enabling                    4    0.291971
# 1        total_costs_mh                    3    0.218978
#
# The patient_services_revenue dataframe has the following missing value counts for "-":
#
#   Column Name  Missing Value Count  % of Total
# 0   total_sfs                    3    0.218978
#
# The personnel_and_visits dataframe has the following missing value counts for "-":
#
#                 Column Name  Missing Value Count  % of Total
# 2     dental_virtual_visits                  155   11.313869
# 8   enabling_virtual_visits                  152   11.094891
# 9         enabling_patients                  104    7.591241
# 7    enabling_clinic_visits                   92    6.715328
# 1      dental_clinic_visits                   46    3.357664
# 3           dental_patients                   42    3.065693
# 5         mh_virtual_visits                   13    0.948905
# 4          mh_clinic_visits                    8    0.583942
# 0    medical_virtual_visits                    6    0.437956
# 6               mh_patients                    6    0.437956
# 10     total_virtual_visits                    2    0.145985
#
# The patients_race dataframe has the following missing value counts for "-":
#
#          Column Name  Missing Value Count  % of Total
# 0    native_hawaiian                   40    2.919708
# 1            pac_isl                   29    2.116788
# 5         unreported                   24    1.751825
# 3             am_ind                    7    0.510949
# 7       lep_patients                    5    0.364964
# 6  hispanic_any_race                    4    0.291971
# 2              black                    3    0.218978
# 4              white                    1    0.072993
#
# The patients_other_demographics dataframe has the following missing value counts for "-":
#
#                 Column Name  Missing Value Count  % of Total
# 8     public_insurance_0_17                  221   16.131387
# 9    public_insurance_18_up                  216   15.766423
# 15    school_based_patients                   86    6.277372
# 17  public_housing_patients                   85    6.204380
# 13         migrant_patients                   57    4.160584
# 14        homeless_patients                   19    1.386861
# 16         veteran_patients                   19    1.386861
# 10   private_insurance_0_17                    9    0.656934
# 5             medicaid_0_17                    5    0.364964
# 7            medicare_18_up                    5    0.364964
# 11  private_insurance_18_up                    4    0.291971
# 6            medicaid_18_up                    3    0.218978
# 4            uninsured_0_17                    2    0.145985
# 3               fpl_unknown                    2    0.145985
# 2              fpl_over_200                    2    0.145985
# 1            fpl_151_to_200                    1    0.072993
# 12               total_0_17                    1    0.072993
# 0            fpl_101_to_150                    1    0.072993

# %%
for key in new_df_dict.keys():
    find_missing_values(new_df_dict, key, '--')
# Out:
# The health_centers does not contain any instances of --.
#
# The health_center_sites does not contain any instances of --.
#
# The health_center_funding does not contain any instances of --.
#
# The health_center_zipcodes dataframe has the following missing value counts for "--":
#
#                          Column Name  Missing Value Count  % of Total
# 2                   MedicarePatients                50594   52.082518
# 0             None_UninsuredPatients                50399   51.881781
# 3                    PrivatePatients                47475   48.871755
# 1  Medicaid_CHIP_OtherPublicPatients                37127   38.219308
# 4              TotalNumberofPatients                19381   19.951205
#
# The health_center_costs does not contain any instances of --.
#
# The patient_services_revenue does not contain any instances of --.
#
# The personnel_and_visits does not contain any instances of --.
#
# The patients_race dataframe has the following missing value counts for "--":
#
#          Column Name  Missing Value Count  % of Total
# 1    native_hawaiian                  681   49.708029
# 2            pac_isl                  542   39.562044
# 4             am_ind                  332   24.233577
# 0              asian                  156   11.386861
# 6         unreported                  108    7.883212
# 8       lep_patients                   66    4.817518
# 3              black                   63    4.598540
# 5              white                   14    1.021898
# 7  hispanic_any_race                    9    0.656934
#
# The patients_other_demographics dataframe has the following missing value counts for "--":
#
#                 Column Name  Missing Value Count  % of Total
# 14         migrant_patients                  233   17.007299
# 15        homeless_patients                  147   10.729927
# 10   public_insurance_18_up                  125    9.124088
# 17         veteran_patients                  106    7.737226
# 9     public_insurance_0_17                   82    5.985401
# 5            uninsured_0_17                   64    4.671533
# 11   private_insurance_0_17                   60    4.379562
# 2            fpl_151_to_200                   35    2.554745
# 3              fpl_over_200                   35    2.554745
# 16    school_based_patients                   32    2.335766
# 4               fpl_unknown                   21    1.532847
# 7             medicaid_0_17                   17    1.240876
# 1            fpl_101_to_150                   14    1.021898
# 13               total_0_17                   10    0.729927
# 8            medicare_18_up                    9    0.656934
# 18  public_housing_patients                    8    0.583942
# 12  private_insurance_18_up                    8    0.583942
# 0             fpl_100_below                    4    0.291971
# 6           uninsured_18_up                    2    0.145985

# %%
for key in new_df_dict.keys():
    find_missing_values(new_df_dict, key, '---')
# Out:
# The health_centers does not contain any instances of ---.
#
# The health_center_sites does not contain any instances of ---.
#
# The health_center_funding does not contain any instances of ---.
#
# The health_center_zipcodes does not contain any instances of ---.
#
# The health_center_costs dataframe has the following missing value counts for "---":
#
#             Column Name  Missing Value Count  % of Total
# 0              BHCMISID                  629   45.912409
# 1           GrantNumber                  629   45.912409
# 2   total_costs_medical                  629   45.912409
# 3    total_costs_dental                  629   45.912409
# 4        total_costs_mh                  629   45.912409
# 5  total_costs_enabling                  629   45.912409
# 6   total_costs_quality                  629   45.912409
# 7       total_cost_care                  629   45.912409
#
# The patient_services_revenue dataframe has the following missing value counts for "---":
#
#        Column Name  Missing Value Count  % of Total
# 0         BHCMISID                  630   45.985401
# 1      GrantNumber                  630   45.985401
# 2    total_charges                  630   45.985401
# 3  total_collected                  630   45.985401
# 4        total_sfs                  630   45.985401
#
# The personnel_and_visits dataframe has the following missing value counts for "---":
#
#                 Column Name  Missing Value Count  % of Total
# 0                  BHCMISID                  579   42.262774
# 1               GrantNumber                  579   42.262774
# 2     medical_clinic_visits                  579   42.262774
# 3    medical_virtual_visits                  579   42.262774
# 4          medical_patients                  579   42.262774
# 5      dental_clinic_visits                  579   42.262774
# 6     dental_virtual_visits                  579   42.262774
# 7           dental_patients                  579   42.262774
# 8          mh_clinic_visits                  579   42.262774
# 9         mh_virtual_visits                  579   42.262774
# 10              mh_patients                  579   42.262774
# 11   enabling_clinic_visits                  579   42.262774
# 12  enabling_virtual_visits                  579   42.262774
# 13        enabling_patients                  579   42.262774
# 14      total_clinic_visits                  579   42.262774
# 15     total_virtual_visits                  579   42.262774
#
# The patients_race does not contain any instances of ---.
#
# The patients_other_demographics does not contain any instances of ---.
